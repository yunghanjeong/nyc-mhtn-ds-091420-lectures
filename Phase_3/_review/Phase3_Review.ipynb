# %% [markdown]
# # Phase 3 Review
#
# Questions pulled from [google doc](https://docs.google.com/document/d/18q-S_0OCtc4X2rjG_-P0CVcbo_fqVuIyyv4Pe9gfKkw/edit)
#
# ## Questions in the Document

# %% [markdown]
# ## Q1.
#
# When using gradient descent to fit a logistic regression model, what does gradient descent determine?
#
# - determines the coefficiences of the features. (parameters of the model)
#
# What does the learning rate do within the gradient descent process and what can happen if you use a non-optimal learning rate?
#
# - it determines the "run" of slope (rise/run) calculation. if the learning rate is too litle the model will take a lot of time to calculate. If the learning rate is too high you may miss the optimal value (minima).

# %% [markdown]
# ## Q2.
#
# When a decision tree classifier splits your observations into two groups, what is the optimal result of those two groups? How do we know if we have the optimal result?
#
# - You have pure leaf (terminal node).
#     - have homogenous results (sub-nodes)
# - The probability of split is equal to the population probability
#     - minimize gini index
#     - measure the information gain before and after

# %% [markdown]
# ## Q3.
#
# If you want to minimize the false negatives of a classifier, which evaluation metric would you use?
#
# - recall (true positive rate)
#
# Accuracy is the most common metric used with classification models, but what is a situation in which this is not a good metric to use? Why?
#
# - when trying to avoid false positive
# - when there is a large class imbalance
#     - the model will be trained heavily towards the majority class

# %% [markdown]
# ## Q4.
#
# What is a potential issue when fitting a model to data that has a high class imbalance? What is one way to mitigate this issue?
#
# - Model will overpredict (bias towards) the majority class
#
# - Mitigate by upsampling the minority class or downsampling the majority class
#     - SMOE?

# %% [markdown]
# ## Q5.
#
# Below is a list of statements describing different models. For the provided list of models, which model best fits each statement. Some statements can apply to more than one model.
#
# Models:   KNN, Logistic Regression, Decision Tree, Random Forest
#
# KNN
# - A quick baseline model to compare against more advanced models
# - Performs poorly when the data isn’t scaled
# - Handles non-linear relationships well
#
# Logistic Regression
# - A highly interpretable model
# - Runs quickly
#
# Decision Tree
# - A highly interpretable model
# - Handles non-linear relationships well
# - Tends to overfit without any regularization
#
# Random Forrest
# - Does a good job of preventing overfitting
# - Handles non-linear relationships well
#
#
#
# 1. Does a good job of preventing overfitting.
# 2. A highly interpretable model.
# 3. Tends to overfit without any regularization.
# 4. A quick baseline model to compare against more advanced models.
# 5. Handles non-linear relationships well.
# 6. Performs poorly when the data isn’t scaled
# 7. Runs quickly

# %% [markdown]
# ## Bonus
#
# What is the difference between hard voting and soft voting?
#
# - hard voting is pure measure of counts
# - soft votings is a comparison of votes multiplied by their probability

# %% [markdown]
# ## Potential Coding Questions
#
# 1. Linear Algebra
# 3. KNN
# 4. Metrics
# 5. confusion matrix and calculated evalution metrics

# %% [markdown]
# ## Linear Algebra

# %%
# numpy dot product
C = A.dot(B) #row of A must match columns of B in length

#numpy cross product
np.cross(x, y) #must be same size

#numpy tranpose
array.T

# solving systems of equations
# X + Y + Z = 1240
# .1X + .2Y + .3Y = 275
# 2X - Z = 0

A = np.array([[1, 1, 1], [.1, .2, .3], [2, 0, -1]])
B = np.array([1240, 276, 0])

np.linalg.solve(A, B.T)

# %% [markdown]
# ![confusion_matrix.PNG](attachment:confusion_matrix.PNG)

# %% [markdown]
# ![Precisionrecall.png](attachment:Precisionrecall.png)

# %% [markdown]
# ![recall_precision.PNG](attachment:recall_precision.PNG)

# %%
metrics.precision_score(y_test, y_pred_class)
metrics.recall_score(y_test, y_pred_class)
metrics.accuracy_score(y_test, preds)
metrics.f1_score(y_test, preds)
